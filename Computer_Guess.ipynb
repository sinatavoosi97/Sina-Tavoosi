# %%
from numpy import random

def get_Information():
    User=int(input("please enter a number between 1 and 1000  :"))
    return User

def computer_Guess():
    guess=random.randint(1,1000)
    return guess

def check_winnner():
    message=""
    User=get_Information()
    message+="\n"
    difference=1
    if 1<=User<=1000:
        count=0
        while difference!=0:
            guess=computer_Guess()
            difference=guess-User
            if 1<=difference<=100:
                message+=(f"{count}---"+"your answer is High"+2*"\n")
                count+=1
            elif difference >100:
                message+=(f"{count}---"+"your answer is  Too High"+2*"\n")
                count+=1
            elif -100<=difference<=-1:
                message+=(f"{count}---"+"your answer is  Too Low"+2*"\n")
                count+=1
            else:
                message+=(50*"👑"+"\n"+50*" "+"Computer Win !"+50*" "+"\n"+50*"👑")
                count+=1
    
    else:
        message+=("you number should be between 1 to 1000, please try again !")
                
    return message
                
        
print(check_winnner())
# Out:
# please enter a number between 1 and 1000  :20
#
# 0---your answer is  Too High
#
# 1---your answer is  Too High
#
# 2---your answer is  Too High
#
# 3---your answer is  Too High
#
# 4---your answer is  Too High
#
# 5---your answer is  Too High
#
# 6---your answer is  Too High
#
# 7---your answer is  Too High
#
# 8---your answer is  Too High
#
# 9---your answer is High
#
# 10---your answer is  Too High
#
# 11---your answer is  Too High
#
# 12---your answer is  Too High
#
# 13---your answer is  Too High
#
# 14---your answer is  Too High
#
# 15---your answer is  Too High
#
# 16---your answer is  Too High
#
# 17---your answer is  Too High
#
# 18---your answer is  Too High
#
# 19---your answer is  Too High
#
# 20---your answer is  Too High
#
# 21---your answer is  Too High
#
# 22---your answer is  Too High
#
# 23---your answer is  Too High
#
# 24---your answer is  Too High
#
# 25---your answer is  Too High
#
# 26---your answer is  Too High
#
# 27---your answer is  Too High
#
# ...
